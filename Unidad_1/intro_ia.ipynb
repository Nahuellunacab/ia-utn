# %% [markdown]
# # Inteligencia Artificial (IAR) 2026
#
# <br> <br>
#
# - Prof. titular: **Alejandro García** <font color=blue>agarcia.ia.utn@gmail.com</font>
# - JTP: **Guillermo Forte** y **Martín Gramática** (TPI)

# %% [markdown]
# ## Nuevo plan de estudios
#
# - Cambios en la educación
#   - Orientación a competencias
#   - Enfoque centrado en el alumno
#   - Resultados de aprendizaje trazables
#   - Sin división teórico/práctica
# - Temas particulares de IAR:
#   - Contenidos nuevos

# %% [markdown]
# ## Condiciones de aprobación
#
# * Leer modalidad académica. Eso es lo que vale.
#
# * Evaluaciones
#   * Parciales: 2 teórico-prácticos
#   * Recuperatorio: 1 teórico-práctico
#   * Trabajo práctico integrador (TPI)
#
# * Condiciones de regularidad
#   * Aprobar todos los parciales
#   * Aprobar el TPI
#   * Aprobar/realizar **todas** las actividades en el tiempo definido
#
# * Aprobación directa
#   * Regularización
#   * Promedio en parciales $\geq 7$
#   * Cada nota de parcial $\geq 6$
#   * Nota de TPI $\geq 7$ (no se promedia con los parciales)

# %% [markdown]
# ## Material de estudio
#   - UV
#     - 2026-K-5-501 (2026-K-Inteligencia Artificial)
#     - Si alguien no está matriculado, automatriculación con clave "IAR2026"
#   - Libro *Inteligencia Artificial, Un Enfoque Moderno*
#     - [Edición 2004 en español](https://drive.google.com/file/d/140MVt67KtdH0vCD27GWnbLM-afAwAnbS/view?usp=sharing)
#     - [Edición 2021 en inglés](https://drive.google.com/file/d/1_HaQJ7cJ4rOMHWQ9rXiOs7nSDmqndkBz/view?usp=sharing)
#   - PDF de la cátedra
#     - Guía de lectura
#     - Material propio
#     - Buscar actualizaciones en la UV
#   - Otros libros y más cosas **obligatorias** (incluyendo los notebooks y presentaciones)

# %% [markdown]
# ## Recomendaciones para el estudio
#
# - Realizar los ejercicios y actividades en tiempo y forma
#   - Acá "forma" quiere decir "resoverlos solos, sin ayuda de ningún tipo".
#   - Están pensados como un complemento necesario para alcanzar el nivel de comprensión esperado.
#   - Se espera que no se puedan resolver facilmente. Entender requiere esfuerzo.
#
# - Junto a cada unidad se proporcionan perguntas "tipo parcial".
#   - Sirven para entender mejor y controlar el nivel alcanzado.
#   - Si se busca ayuda para resolverlo, no mejora el nivel y se pierde la utilidad como referencia.
#
# - La asistencia y participación en las clases es necesaria aunque no sea un requisito de regularidad.

# %% [markdown]
# ## Jupyter notebook
#
# Vamos a usar Jupyter para ejemplos, ejercicios y presentaciones. Este notebook casi no tiene código porque es una introducción. Los próximos sí. A practicar!

# %%
print("Hola Jupyter\n")
for i in range(5):
    print(i)
# Out:
# Hola Jupyter
#
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# # Inteligencia Artificial
#
# - Definiciones y enfoques
# - ¿Por qué es interesante la IA?
# - Fundamentos
# - Breve historia
# - Corrientes
# - Presente

# %% [markdown]
# Primero, una aclaración sobre el término Inteligencia Artificial (IA).
#
# * Durante este curso, **Inteligencia Artificial es el nombre de una disciplica científica**.
#
# * Es común escuchar o leer una nueva acepción para "IA" nacida del marketing o tendencias sociales.
#
# * IA (acá) no es una forma de referirse a una solución particular.
#
# <br>
# <br>
# <br>
# <center>
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Definiciones y enfoques de la IA

# %% [markdown]
# <center>
#
# <big> <b> La inteligencia (general) es "la capacidad de entender, asimilar, elaborar información y utilizarla para resolver problemas" (Wikipedia). </b> </big>

# %% [markdown]
# Para Inteligencia <b>Artificial</b> las definiciones de los autores actuales varían en torno a dos dimensiones principales:
# <br>
# - Razonamiento-conducta
# - Eficiencia humano-ideal
#
# <br>
# <center><img src="https://drive.google.com/uc?id=1I3qGjllf48QjEQFNK88UbefYwZYtVkn5" width="70%"></center>

# %% [markdown]
# <br>
# Para nuestra materia:
#
# <big> <b>"La capacidad de realizar tareas que, por el momento, los humanos hacen mejor" </b> </big>
#
# <br>
# <b>Elaine Rich y Kevin Knight<b/>
#
# <br>
#
# <br>

# %% [markdown]
# ## ¿Por qué es interesante la IA?
#
# * Sentido de la identidad
# * Comprensión de entidades inteligentes
# * Es un problema complejo, pero...
# * El estudio de la inteligencia es una de las disciplinas más antigua
# * ¿Qué pasará en el futuro?
# * Otras razones más mundanas

# %% [markdown]
# ### Sentido de la identidad
#
# El hombre se ha aplicado a sí mismo el nombre científico de <b> <i> homo sapiens </i> </b> (hombre sabio o "capaz de conocer") como una valoración de la trascendencia de nuestras habilidades mentales tanto para la vida cotidiana como en nuestro propio sentido de la identidad.
# <center><img src="https://drive.google.com/uc?id=12g6bTMs_RqWIajoUreTOcmVJlkG0DCrk" width="50%"></center>

# %% [markdown]
# ### Comprensión de entidades inteligentes
#
# Los esfuerzos en el campo de la IA se enfocan en lograr la compresión de entidades inteligentes. Por eso, una de las razones de su estudio es aprender más sobre nosotros mismos. A diferencia de la filofía y de la psicología, que también se ocupan de la inteligencia, los esfuerzos de la IA están encaminados tanto a la comprensión de entidades inteligentes como su construcción. Otra razón por la que se estudia la IA es que las entidades inteligentes así construidas son interesantes y útiles por derecho propio. ~~No obstante las fases tempranas en las que aún se encuentra la IA, ha sido posible crear diversos productos, importantes y sorprendentes~~.

# %% [markdown]
# ### Es un problema complejo, pero... la solución existe
#
# El problema que aborda la IA es uno de los más complejos, pero a diferencia de la investigación en torno al desplazamiento a mayor velocidad que la luz o de un dispositivo antigravitatorio, el investigador del campo de la IA cuenta con pruebas contundentes de que tal búsqueda es factible. Todo lo que este investigador tiene que hacer es mirarse en un espejo para tener ante sí un ejemplo de sistema inteligente.

# %% [markdown]
# ### El estudio de la inteligencia es una de las disciplinas más antiguas
#
# Por más de 2000 años los filósofos se han preguntado cómo se ve, aprende, recuerda y razona. La llegada de las computadoras a principio de la década de los cincuenta permitió pasar de la especulación, a nivel de charlas de café, en torno a estas facultades mentales a su abordaje mediante una auténtica disciplina teórica y experimental.
# <br>
# <br>
# <center><img src="https://drive.google.com/uc?id=1IWDbu_rS25M514bEDWldUBHWN8MyFNqh" width="30%"></center>
#  <center>Frank Rosenblatt, implementador del perceptron</center>

# %% [markdown]
# #### Fundamentos (de otras ciencias)
#
# Si bien la IA es un campo joven, es heredera de diversas ideas, puntos de vista y técnicas de otras disciplinas. Estas disciplinas son:
#
# - Filosofía
# - Matemáticas
# - Psicología
# - Neurología
# - Computación
# - Lingüística

# %% [markdown]
# #### Breve historia y algunos hitos
# - En 1936 Alan Turing crea la Máquina de Turing, la base de las computadoras.
# - En 1943,  Warren McCulloch y Walter Pitts crean la primera neurona artificial.
# - Alan Turing, consciente de los alcances de su máquina, define en 1950 el Test de Turing. Una prueba para para determinar si una máquina es inteligente (como un humano).
# - En 1956, John McCarthy convocó el <i>Dartmouth workshop</i>, una reunión de dos meses de duración a la que asistieron cerca de 10 científicos que trabajaban en temas relacionados con "máquinas pensantes". Estuvieron, entre otros, Marvin Minsky, Nathaniel Rochester y Claude Shannon. En esta reunión se acuñó el nobre "Inteligencia Artificial.
# - La primera década estuvo marcada por un optimismo exagerado. Se rápidamente resolvieron problemas como la demostración de teoremas y se logró que las másquinas superaran a los humanos en algunos juegos simples.
# - Etapa de depresión (<i>AI winter</i>). Cuando se intentaron atacar problemas del dominio del sentido común o aquellos que necesitan de conocimiento general, como los relacionados con el lenguaje, los esfuerzos no fueron suficientes. Esta situación llevó a un desanimo generalizado y a la pérdida de inversiones.
# - Después de la etapa de depresión, ya en los 80's, la IA artificial resurgió de la mano de los Sistemas Expertos (los veremos en el 2do cuatrimestre). Desde ese momento el área no deja de crecer. Los sistemas de visión artificial y los de reconocimiento de patrones han provisto innumerables soluciones en los últmos años. La cantidad de datos disponibles, los recursos computacionales y los avances como el de las redes neuronales profundas (<i>deep learning</i>) han formado un círculo virtuoso donde tanto las empresas como la comunidad cietífica invierten cada vez más recursos. Los resultados están a la vista.

# %% [markdown]
# #### Corrientes
#
# Desde los inicios de la IA se plantearon dos enfoques diferentes, uno por parte de los investigadores del MIT y otro por los del Carnegie-Mellon. Estos caminos se fueron alejando hasta llegar a plantearse un distanciamiento que caracterizó las investigaciones en IA de los veinte años siguientes y que fue sin lugar a dudas muy perjudicial por el atraso que provocó en algunas líneas de investigación.

# %% [markdown]
# <b>Corriente conexionista - subsimbólica - ascendente</b>.
#
# La escuela liderada por los investigadores de la Universidad de Carnegie-Mellon proponía desarrollar modelos del comportamiento humano a partir de elementos que simularan en todo lo posible al cerebro con un enfoque claramente cognitivo. Así iniciaron una corriente denominada "de aproximaciones subsimbólicas" que sigue un diseño de modelo "ascendente", comenzando en el nivel más bajo y operando hacia niveles superiores. Según esta corriente, para concebir máquinas inteligentes hay que seguir muchos de los pasos evolutivos que acompañaron el desarrollo de la inteligencia en los seres vivos. De esta forma hay que comenzar por replicar la capacidad de procesamiento de señales y subir por la cadena evolutiva en pasos sucesivos, construyendo progresivos niveles superiores de inteligencia que constituirán las bases sólidas para los pasos siguientes. Al amparo de esta propuestase desarrollaron los modelos conexionistas, redes neuronales inspiradas en los modelos biológicos.
#
#
#
# <b>Corriente tradicional - simbólica - descendente</b>.
#
# La segunda escuela, liderada por Minsky y McCarthy del MIT orientó su actividad a obtener comportamientos "inteligentes" sin procurar que la estructura de los componentes tuviese semejanza con sus equivalentes biológicos y llegó a su mayor auge en los primeros 20 años de la IA. Esta escuela iniciada en el MIT fue denominada "tradicional", "de procesamiento de símbolos" o "de diseño descendente" y se apoyó en representar el conocimiento mediante sentencias declarativas y en la deducción de sus consecuencias a partir de la aplicación de reglas de inferencia. Sin embargo, poco a poco se fue comprobando que muchas de las soluciones propuestas eran apropiadas para modelos pequeños, pero completamente ineficientes o inaplicables cuando se pretendía resolver problemas de tamaño real. Los investigadores se encontraron con que sus sistemas sucumbían ante la creciente longitud y complejidad de su programación.

# %% [markdown]
# #### Presente
#
# * Empresas y universidades, muchas veces en conjunto, no dejan de romper barreras.
# * Las tareas que son realizadas mejor por los humanos que por las máquinas se reducen vertiginosamente.
# * Existen:
#   * Autos que se manejan solos
#   * Máquinas que responden preguntas de conocimiento general mejor que una persona
#   * Reconocimiento de objetos con presición superior a la humana
#   * Etc
#
# Durante este curso veremos las bases de las técnicas más importantes utilizadas en estos logros.

# %% [markdown]
# ### Otras razones (más mundanas) para hacer IA
#
# <center><img src="https://drive.google.com/uc?id=1eR7AdGdkF__0NfURQp8v8b6Ku4yDnyrg" width="70%"></center>

# %% [markdown]
# <center><img src="https://drive.google.com/uc?id=1IaOZE3itHCtcBELntrb_i0JK5sBZOmdy" width="60%"></center>
# <center>Slide tomado prestado de Pedro Gutierrez (España)</center>

# %% [markdown]
# **Algunos trabajos/roles en IA**
#
#
# <center><img src="https://drive.google.com/uc?id=1TL9ByGA3MXs-QG7kLZ9ZDAFDCVPSP0XF" width="60%"></center>
# <center>Algunos de los trabajos en IA ;)</center>

# %% [markdown]
# A nivel organizaciones
#
# <br>
# <center>
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### ¿Qué pasará en el futuro?

# %% [markdown]
# <br>
# <center><img src="https://drive.google.com/uc?id=1yUc21OKMdOK6bPdl3JFw9S_6QRcQoIPL" width="80%"></center>
#
# Si bien nadie podría pronosticar con toda precisión lo que se podría esperar en el futuro, es evidente que las computadoras que posean inteligencia a nivel humano (o superior) tendrán repercusiones muy importantes en nuestra vida diaria así como en el devenir de la civilización.
#
# El caso extremo es la singularidad tecnológica. Un punto en el tiempo donde, para algunos pensadores, la inteligencia artificial superará a la humana (AGI). Es imposible que nuestra mente pueda imaginar lo que pasaría después, de la misma forma en que los monos no pueden comprender lo que hacemos los humanos.

# %% [markdown]
# ## ¿Se puede evitar la AGI?
#
# <center>
#
# **Usted está aquí**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <center>
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <center>
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <center>
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## ¿Qué riesgos asociados tiene la IA?
#
# * Apocalipsis (guerra humano vs máquina)?
# * Derrumbe económico/social (trabajo)?
# * Pérdida de la dignidad?
# * Manipulación?
# * Control/Pérdida de privacidad?
# * Delitos?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Actividad para esta semana**:
# - Mirar este [video](https://www.youtube.com/watch?v=86k8N4YsA7c)
# - Leer el [AI index](https://hai.stanford.edu/ai-index) de Stanford
# - Y ya que estamos... este [artículo](https://blog.cosmos-institute.org/p/the-claude-boys?fbclid=IwY2xjawMIdv5leHRuA2FlbQIxMABicmlkETFtZUQ4dlYxMlVvM1oxVUt6AR4odRIJad4yJYLinGmuzu6-NT2V4RCnbV1kHlP0x71ooOQ6rZPKIQC0OvNR4w_aem_iqEYxlxGhWu9Hgfti8xZtw) también
# - Responder las siguientes preguntas con apreciaciones personales:
#   - ¿Qué riesgos tienen asociados los últimos avances en IA?
#   - ¿Cuáles son las actividades que no están amenazadas por la IA?
#   - ¿Se logrará la AGI?
#   - ¿Qué riesgos traería la AGI y/o el camino hacia ella?
#
# AGI: IA general (superior a la humana)
#
#
# Discutir en el foro del curso y guardar la evidencia

# %% [markdown]
# <center>
#
# ## ¿Cómo empezar con IA en la UTN?
#
#
# ![logo GIA small.png](data:image/png;base64,...)
#
# https://www.investigacion.frc.utn.edu.ar/gia/

# %% [markdown]
# # Agentes Inteligentes
#
# Un enfoque para pensar en soluciones desarrollos de IA

# %% [markdown]
# **Un agente (no necesariamente racional) es cualquier cosa capaz de percibir su medioambiente con la ayuda de sensores y actuar en ese medio utilizando actuadores**
# <center>
#
# ![Screenshot from 2023-03-20 11-25-04.png](data:image/png;base64,...)
#
# </center>
#
# - Se trabajará con la hipótesis general de que cada agente puede percibir sus propias acciones (pero no siempre sus efectos)
#
# - La noción de agente es supuestamente una herramienta para el análisis de sistemas, y no una caracterización absoluta que divida el mundo entre agentes y no agentes

# %% [markdown]
# **Agente racional**
#
# - Un agente racional es aquel que hace lo correcto
# - Como primera aproximación, se puede decir que lo correcto es aquello que permite al agente obtener un mejor resultado
# - Es necesaria una forma de medir el éxito

# %% [markdown]
# **Especificación de la tarea**
# - Descripción del entorno
# - Descripción de sensores y actuadores
# - Medida de rendimiento

# %% [markdown]
# **Racionalidad**
# - La racionalidad en un momento determinado depende de cuatro factores:
#   - La medida de rendimiento que define el criterio de éxito.
#   - El conocimiento previo del medio que tiene el agente.
#   - Las acciones que el agente puede llevar a cabo.
#   - La secuencia de percepciones del agente hasta este momento.

# %% [markdown]
# **Definición de agente racional**
#
# "En cada posible secuencia de percepciones, un agente racional debe ejecutar aquella acción que supuestamente maximice su medida de rendimiento, basándose en las evidencias aportadas por la secuencia de percepciones y en el conocimiento incorporado que tenga el agente"

# %% [markdown]
# **Aprendizaje**
#
# La configuración inicial del agente puede reflejar un conocimiento preliminar del entorno, pero a medida que el agente adquiere experiencia éste puede modificarse y aumentar.

# %% [markdown]
# ### La naturaleza del entorno (ambiente) del problema

# %% [markdown]
# Antes que nada, **¿cuáles son los problemas dentro del alcance de la IA?**
#
# - Una entidad inteligente es capaz de resolverlo (o podría serlo)
# - No existe una solución algorítmica

# %% [markdown]
# **Propiedades de los entornos de trabajo**
# - Dimensiones
#   - Totalmente observable vs. parcialmente observable.
#   - Determinista vs. estocástico
#   - Episódico vs. secuencial
#   - Estático vs. dinámico
#   - Discreto vs. continuo
#   - Agente individual vs. multiagente
#     - entorno multiagente competitivo
#     - entorno multiagente cooperativo
#     - en entornos multiagnetes puede emerger la comunicación
#   - Conocido vs. desconocido

# %% [markdown]
# **Otra actividad**
#
# **Completar la siguiente tabla**:
#
# * Para editar la tabla es necesario copiar el notebook. Después de copiarlo, compartirlo (con permiso de lectura para cualquiera que tenga el link) y pegar el link en la actividad correspondiente de la UV.
# * En base a la clasificación anterior, marcar con una 'X' cuando corresponda y con un '' cuando no corresponda.
# * En el campo "IA?" indicar si el problema está dentro del alcance de la IA.

# %%
import pandas as pd

df = pd.DataFrame(columns=['Problema', 'IA?', 'Determinista', 'Episódico', 'Estático', 'Discreto', 'Individual', 'Conocido'],
                  data=[['Diagnóstico médico','?', '?', '?', '?', '?', '?', '?'],
                        ['Jugar (y ganar) al ta-te-ti','?', '?', '?', '?', '?', '?', '?'],
                        ['Jugar (y ganar) al fútbol','?', '?', '?', '?', '?', '?', '?'],
                        ['Jugar (y ganar) a la lotería','?', '?', '?', '?', '?', '?', '?'],
                        ['Jugar (y ganar) al ajedrez','?', '?', '?', '?', '?', '?', '?'],
                        ['Administrar una empresa','?', '?', '?', '?', '?', '?', '?'],
                        ['Crear una estrategia judicial','?', '?', '?', '?', '?', '?', '?'],
                        ['Demostrar un teorema matemático','?', '?', '?', '?', '?', '?', '?'],
                        ['Refutar un teorema matemático','?', '?', '?', '?', '?', '?', '?'],
                        ['Andar en bici','?', '?', '?', '?', '?', '?', '?'],
                        ['Hacer un chiste','?', '?', '?', '?', '?', '?', '?']])

df
# Out:
#                            Problema IA? Determinista Episódico Estático  \
# 0                Diagnóstico médico   ?            ?         ?        ?
# 1       Jugar (y ganar) al ta-te-ti   ?            ?         ?        ?
# 2         Jugar (y ganar) al fútbol   ?            ?         ?        ?
# 3      Jugar (y ganar) a la lotería   ?            ?         ?        ?
# 4        Jugar (y ganar) al ajedrez   ?            ?         ?        ?
# 5           Administrar una empresa   ?            ?         ?        ?
# 6     Crear una estrategia judicial   ?            ?         ?        ?
# 7   Demostrar un teorema matemático   ?            ?         ?        ?
# 8     Refutar un teorema matemático   ?            ?         ?        ?
# 9                     Andar en bici   ?            ?         ?        ?
# 10                  Hacer un chiste   ?            ?         ?        ?
#
#    Discreto Individual Conocido
# 0         ?          ?        ?
# 1         ?          ?        ?
# ...

# %% [markdown]
# ### Estructura de los agentes
#
# - Agentes reactivos
#   - Reglas (conexiones *si-entonces*)
#   - Pueden ser:
#     - Simples
#       - Percepciones actuales
#     - Basados en modelos
#       - Estado interno (almacenan información de las partes del mundo que no pueden ver)
# - Agentes basados en objetivos
# - Agentes basados en utilidad

# %% [markdown]
# ### Agentes que aprenden
#
# - Elemento de actuación
# - Elemento de aprendizaje
# - Crítica
# - Generador de problemas
#
# <center>
#
# ![image.png](data:image/png;base64,...)
#
# </center>
