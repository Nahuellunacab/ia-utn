# %%
import pandas as pd

df = pd.DataFrame(columns=['Problema', 'IA?', 'Determinista', 'Episódico', 'Estático', 'Discreto', 'Individual', 'Conocido'],
                  data=[['Diagnóstico médico','X', '', '', '', '', '', ''],
                        ['Jugar (y ganar) al ta-te-ti','X', 'X', '', 'X', 'X', 'X', 'X'],
                        ['Jugar (y ganar) al fútbol','X', '', '', '', '', '', ''],
                        ['Jugar (y ganar) a la lotería','', '', 'X', 'X', 'X', 'X', 'X'],
                        ['Jugar (y ganar) al ajedrez','X', 'X', '', 'X', 'X', 'X', 'X'],
                        ['Administrar una empresa','X', '', '', '', '', '', ''],
                        ['Crear una estrategia judicial','X', '', '', '', '', '', ''],
                        ['Demostrar un teorema matemático','X', 'X', '', 'X', 'X', 'X', 'X'],
                        ['Refutar un teorema matemático','X', 'X', '', 'X', 'X', 'X', 'X'],
                        ['Andar en bici','X', '', '', '', '', 'X', ''],
                        ['Hacer un chiste','X', '', 'X', 'X', 'X', 'X', '']
                       ])

df
# Out:
#                            Problema IA? Determinista Episódico Estático  \
# 0                Diagnóstico médico   X
# 1       Jugar (y ganar) al ta-te-ti   X            X                  X
# 2         Jugar (y ganar) al fútbol   X
# 3      Jugar (y ganar) a la lotería                          X        X
# 4        Jugar (y ganar) al ajedrez   X            X                  X
# 5           Administrar una empresa   X
# 6     Crear una estrategia judicial   X
# 7   Demostrar un teorema matemático   X            X                  X
# 8     Refutar un teorema matemático   X            X                  X
# 9                     Andar en bici   X
# 10                  Hacer un chiste   X                      X        X
#
#    Discreto Individual Conocido
# 0
# 1         X          X        X
# 2
# 3         X          X        X
# 4         X          X        X
# 5
# 6
# 7         X          X        X
# 8         X          X        X
# 9                    X
# ...
